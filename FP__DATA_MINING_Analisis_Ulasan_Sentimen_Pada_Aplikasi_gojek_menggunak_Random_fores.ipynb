# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#instalasi modul untuk scraping data dari playstore
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.6-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.6

# %%
 #import library app google play scraper
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews  #import review dan sorting dari playstore scraper
result, continuation_token = reviews(
    'com.gojek.app',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000, # mengambil 1000 data
    filter_score_with=None
)

# %%
print(result[0])  #menampilkan data ke 1
# Out:
# {'reviewId': 'daa95a25-b8f2-42dd-82d9-be39f7dead8d', 'userName': 'Inas Nuhafifa', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXe4x5lTspRATYYCasch72RMJDeS-gzfjLsioZ7zkSRICc', 'content': 'tolong kualitas kendaraan sangat diperhatikan, harga lebih mahal daripada aplikasi lain, sehingga ekspektasi motor layak, tapi sering sekali saya dapat kendaraan yang sangat tidak layak, seperti gak bisa lari motornya dan pijakan kaki gak ada atau mobil yang tidak bisa menyalakan AC', 'score': 1, 'thumbsUpCount': 40, 'reviewCreatedVersion': '4.84.1', 'at': datetime.datetime(2024, 3, 19, 6, 19, 26), 'replyContent': 'Hai Kak Inas, mohon maaf atas ketidaknyamanannya. Laporan yang kamu berikan akan menjadi masukan bagi kami untuk terus meningkatkan kualitas layanan kami ke depannya. Jika kamu memiliki pertanyaan atau kendala lainnya, silakan kunjungi menu Bantuan di aplikasi Gojek kamu. ^Tria', 'repliedAt': datetime.datetime(2024, 3, 19, 6, 35, 27), 'appVersion': '4.84.1'}

# %%
df = pd.read_csv("/content/drive/MyDrive/BIG DATA DAN DATA MINING/FP2/datagojek (2).csv")
df
# Out:
#                  userName  score                   at  \
# 0     Eva yuliana Safitri      1  2023-11-18 15:44:10
# 1            Felix Tumale      1  2023-11-12 03:56:28
# 2           Ikanova Tusya      1  2023-11-16 11:25:47
# 3                  Junnn.      3  2023-11-13 06:56:31
# 4                 Nin Kun      1  2023-11-25 10:33:23
# ..                    ...    ...                  ...
# 995        Muhammad Yusup      1  2023-11-26 07:28:57
# 996         rajikan sidik      1  2023-11-28 19:35:17
# 997          Diki Saputra      1  2023-11-30 15:17:32
# 998   Yanti wildandelisha      3  2023-12-01 23:29:46
# 999  Sutan officer Chanel      1  2023-11-09 05:11:10
#
#                                                content
# 0    Aplikasi sering nge-hang. Tiba² "tutup aplikas...
# 1    Aplikasinya akhir-akhir ini bermasalah. (1) lo...
# 2    Ada apa ya dengan gopay later saya, pdhal sebe...
# 3    Apaan sih ni aplikasi, tiba tiba force close l...
# 4    Kenapa saat coba memesan untuk lokasi di luar ...
# ..                                                 ...
# 995  Sedikit pengalaman saya mengenai aplikasi goje...
# 996  "Gak dapat sinyal inyernet, nih" padahal sinya...
# 997  Bintang satu saya beli paket data dan status d...
# 998  Aplikasi paylater error trus dan tidak bisa di...
# 999  udah beda , masih bagus versi lama, daftar gam...
#
# [1000 rows x 4 columns]

# %%
data = pd.DataFrame(np.array(result), columns=['review']) #mengambil kolom review

data = data.join(pd.DataFrame(data.pop('review').tolist()))

data #menampilkan seluruh data
# Out:
#                                  reviewId                   userName  \
# 0    daa95a25-b8f2-42dd-82d9-be39f7dead8d              Inas Nuhafifa
# 1    795c0fb0-e43c-4b08-a62a-30113f5696e5                 miss herna
# 2    619336fc-b0cc-4df5-8ad9-9ffff4ab1d34  Aditarifa Rizki Pratigina
# 3    ec39b154-bd25-446c-bb55-5377f55d3185                 triyoga 47
# 4    fa3053fc-20a9-4da9-85e1-d810d5e0f8a9            Muhammad Krisna
# ..                                    ...                        ...
# 990  20731986-aca5-4ac9-ace6-9ae002965e1c                dlnvyt rose
# 991  13a0be99-3f77-4912-bca5-9559c376b645              Robby Surgery
# 992  12a01d18-86ac-47b7-9b29-fed2c47144f6             April Paserang
# 993  f0dd4c71-2909-40b9-9de8-48b6786e863d               Arifki Putra
# 994  cbf4bb5c-593c-448a-9216-30ff7e009518                  Ummi Hani
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a/ACg8oc...
# ..                                                 ...
# 990  https://play-lh.googleusercontent.com/a-/ALV-U...
# 991  https://play-lh.googleusercontent.com/a-/ALV-U...
# 992  https://play-lh.googleusercontent.com/a-/ALV-U...
# 993  https://play-lh.googleusercontent.com/a/ACg8oc...
# 994  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    tolong kualitas kendaraan sangat diperhatikan,...      1             40
# 1    Aplikasi yang cukup membuat emosi di pagi hari...      1             51
# 2    Fitur chat-nya sering lelet bangeet. Chat diki...      4            901
# 3    tahun kemarin bagus karena bisa buat bayar pbb...      1              1
# 4    Sangat tidak efektif, saldo gopay 66ribu gak p...      1              2
# ..                                                 ...    ...            ...
# 990  Akhirnya setelah sering dapet driver yg jarak ...      4              0
# 991  Sejauh ini aplikasi ini yg paling bermanfaat d...      5              0
# 992  Harga makin naik harusnya diimbangi dengan pel...      1              1
# 993  Drivernya baik,ramah,sopan pula dalam bertutur...      5              0
# 994  Bintang satu gk akan berubah, percuma ngasih p...      1              1
#
#     reviewCreatedVersion                  at  \
# 0                 4.84.1 2024-03-19 06:19:26
# 1                 4.84.1 2024-03-19 01:08:20
# 2                 4.81.1 2024-01-26 09:22:47
# 3                 4.84.1 2024-03-19 05:50:24
# 4                 4.84.1 2024-03-15 04:26:09
# ..                   ...                 ...
# 990               4.83.1 2024-02-28 01:15:31
# 991               4.83.1 2024-03-09 05:01:24
# 992               4.82.1 2024-02-04 13:16:27
# 993               4.82.1 2024-02-09 12:57:06
# 994               4.82.1 2024-02-21 03:18:42
#
#                                           replyContent           repliedAt  \
# 0    Hai Kak Inas, mohon maaf atas ketidaknyamanann... 2024-03-19 06:35:27
# 1    Hai Kak Herna, mohon maaf atas ketidaknyamanan... 2024-03-19 03:13:05
# 2                                                 None                 NaT
# 3    Mohon maaf atas kendalanya, Kak Triyoga. Terka... 2024-03-19 06:07:05
# 4    Hai Kak Krisna, pastikan internetmu stabil dan... 2024-03-15 05:36:51
# ..                                                 ...                 ...
# 990  Hai Kak Rose, mohon maaf atas ketidaknyamanann... 2024-02-26 01:44:13
# 991                                               None                 NaT
# 992  Hai, mohon maaf atas kendalanya. Kesulitan unt... 2021-12-07 03:01:15
# 993                                               None                 NaT
# 994  Mohon maaf atas kendalanya, Kak Hani. Kesulita... 2024-02-21 04:10:09
#
#     appVersion
# 0       4.84.1
# 1       4.84.1
# 2       4.81.1
# 3       4.84.1
# 4       4.84.1
# ..         ...
# 990     4.83.1
# 991     4.83.1
# 992     4.82.1
# 993     4.82.1
# 994     4.82.1
#
# [995 rows x 11 columns]

# %%
scrappeddata1 = data[['content','score','at']] #hanya mengambil 3kolom yaitu: content, score, at
sorteddata = scrappeddata1.sort_values(by='at', ascending=True) #disorting berdasarkan review terbaru
sorteddata.head()
# Out:
#                                                content  score  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1
# 866  Developer jangan korupsi ya. Saya yakin sekela...      1
# 870  Gojek loading doang tapi tidak bisa digunakan....      1
# 484  Entah mengapa jadi lebih sering force close, l...      2
# 869  perpindahan antar menu jadi sering error. seri...      1
#
#                      at
# 864 2023-10-13 04:38:58
# 866 2023-10-14 01:07:28
# 870 2023-10-14 22:52:22
# 484 2023-10-17 05:11:19
# 869 2023-10-17 09:46:02

# %%
sorteddata.info() #menampilkan informasi sorted data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 995 entries, 864 to 946
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  995 non-null    object
#  1   score    995 non-null    int64
#  2   at       995 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 31.1+ KB

# %%
sorteddata['Year'] = sorteddata['at'].dt.year #memisahkan kolom tahun
sorteddata['Month'] = sorteddata['at'].dt.month #memisahkan kolom bulan
sorteddata['Day'] = sorteddata['at'].dt.day #memisahkan kolom hari

# %%
sorteddata #menampilkan dataframe sorted data
# Out:
#                                                content  score  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1
# 866  Developer jangan korupsi ya. Saya yakin sekela...      1
# 870  Gojek loading doang tapi tidak bisa digunakan....      1
# 484  Entah mengapa jadi lebih sering force close, l...      2
# 869  perpindahan antar menu jadi sering error. seri...      1
# ..                                                 ...    ...
# 53   Mau pesen udh pake vocer malah gabisa muncul n...      1
# 111  Pesanan Gojek tdk bisa dibatalkan. Driver sala...      1
# 905  Kesal banget sama gofood, pesanan gabisa dibat...      1
# 464  Harganya mahal wkwkw gacoan 11 ribu jadi 16 ya...      1
# 946  Kenapa baru sekarang ada update kalo saldo hil...      1
#
#                      at  Year  Month  Day
# 864 2023-10-13 04:38:58  2023     10   13
# 866 2023-10-14 01:07:28  2023     10   14
# 870 2023-10-14 22:52:22  2023     10   14
# 484 2023-10-17 05:11:19  2023     10   17
# 869 2023-10-17 09:46:02  2023     10   17
# ..                  ...   ...    ...  ...
# 53  2024-03-19 07:04:38  2024      3   19
# 111 2024-03-19 10:45:27  2024      3   19
# 905 2024-03-19 10:51:37  2024      3   19
# 464 2024-03-19 11:09:14  2024      3   19
# 946 2024-03-19 12:00:59  2024      3   19
#
# [995 rows x 6 columns]

# %%
df = sorteddata[['content','score','Year','Month','Day']] #variabel df diisi dengan kolom content,score,year,month,day dari sorted data
df #menampilkan dataframe df
# Out:
#                                                content  score  Year  Month  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1  2023     10
# 866  Developer jangan korupsi ya. Saya yakin sekela...      1  2023     10
# 870  Gojek loading doang tapi tidak bisa digunakan....      1  2023     10
# 484  Entah mengapa jadi lebih sering force close, l...      2  2023     10
# 869  perpindahan antar menu jadi sering error. seri...      1  2023     10
# ..                                                 ...    ...   ...    ...
# 53   Mau pesen udh pake vocer malah gabisa muncul n...      1  2024      3
# 111  Pesanan Gojek tdk bisa dibatalkan. Driver sala...      1  2024      3
# 905  Kesal banget sama gofood, pesanan gabisa dibat...      1  2024      3
# 464  Harganya mahal wkwkw gacoan 11 ribu jadi 16 ya...      1  2024      3
# 946  Kenapa baru sekarang ada update kalo saldo hil...      1  2024      3
#
#      Day
# 864   13
# 866   14
# 870   14
# 484   17
# 869   17
# ..   ...
# 53    19
# 111   19
# 905   19
# 464   19
# 946   19
#
# [995 rows x 5 columns]

# %%
df['score'].value_counts() #menghitung total masing2 score rating dengan skala 1-5
# Out:
# 1    585
# 2    131
# 3    110
# 5    110
# 4     59
# Name: score, dtype: int64

# %% [markdown]
# # Kolom Sentimen
# Menambahkan kolom sentimen dengan kriteria, score 1-2 --> negatif dengan kode -1, score 3 adalah netral dengan kode angka 0 dan score 4-5 adalah positif dengan kode 1

# %%
sentimen = []
for index, row in df.iterrows():
    if row['score'] > 3 :
        sentimen.append(1)
    elif row['score'] == 3:
        sentimen.append(0)
    else:
        sentimen.append(-1)
df['sentiment'] = sentimen
df.head()
# Out:
#                                                content  score  Year  Month  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1  2023     10
# 866  Developer jangan korupsi ya. Saya yakin sekela...      1  2023     10
# 870  Gojek loading doang tapi tidak bisa digunakan....      1  2023     10
# 484  Entah mengapa jadi lebih sering force close, l...      2  2023     10
# 869  perpindahan antar menu jadi sering error. seri...      1  2023     10
#
#      Day  sentiment
# 864   13         -1
# 866   14         -1
# 870   14         -1
# 484   17         -1
# 869   17         -1

# %%
import pandas as pd
import string
import nltk #import library natural languange toolkit

# %%
#menghitung total masing2 nilai sentiment baik negative, netral maupun positi
df['sentiment'].value_counts()
# Out:
# -1    716
#  1    169
#  0    110
# Name: sentiment, dtype: int64

# %% [markdown]
# # Tahapan Preprocessing

# %%
nltk.download('punkt') #mengunduh package punkt
nltk.download('stopwords') #mengunduh package stopword
nltk.download('wordnet') #mengunduh package wordnet
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#Menghapus URL dari kolom konten
df['content'] = df['content'].str.replace('https\S+', ' ', case=False)

#Merubah Teks Jadi Lower Case
df['content'] = df['content'].str.lower()

#Menghapus mention
df['content'] = df['content'].str.replace('@\S+', ' ', case=False)

#Menghapus Hashtag
df['content'] = df['content'].str.replace('#\S+', ' ', case=False)

#menghapus next karakter
df['content'] = df['content'].str.replace("\'\w+", ' ', case=False)

#Menghapus tanda baca
df['content'] = df['content'].str.replace("[^\w\s]", ' ', case=False)

#Menghapus extra whitespace
df['content'] = df['content'].str.replace("\s(2)", ' ', case=False)

# %% [markdown]
# # Tokenizing
#
# proses pemotongan teks menjadi bagian-bagian yang lebih kecil, yang disebut token. Pada proses ini juga dilakukan penghilangan angka, tanda baca dan karakter lain yang dianggap tidak memiliki pengaruh terhadap pemrosesan teks.

# %%
# impor word_tokenize dari modul nltk
from nltk.tokenize import word_tokenize

# %%
from nltk.tokenize import RegexpTokenizer #import package RegexTokenizer
regexp = RegexpTokenizer('\w+')
df['content_token']=df['content'].apply(regexp.tokenize) #menambahkan kolom content_token pada dataframe df
df.head(3)
# Out:
#                                                content  score  Year  Month  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1  2023     10
# 866  developer jangan korupsi ya  saya yakin sekela...      1  2023     10
# 870  gojek loading doang tapi tidak bisa digunakan ...      1  2023     10
#
#      Day  sentiment                                      content_token
# 864   13         -1  [minimal, kalau, mau, perubahan, yang, lebih, ...
# 866   14         -1  [developer, jangan, korupsi, ya, saya, yakin, ...
# 870   14         -1  [gojek, loading, doang, tapi, tidak, bisa, dig...

# %% [markdown]
# # **Filtering** (Stopword Removal)
# Filtering adalah tahap mengambil kata-kata penting dari hasil token dengan menggunakan algoritma stoplist (membuang kata kurang penting) atau wordlist (menyimpan kata penting).
#
# Stopword adalah kata umum yang biasanya muncul dalam jumlah besar dan dianggap tidak memiliki makna.

# %%
import nltk

nltk.download('stopwords') #mengunduh package stopword
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords #mengimport stopword

# membuat daftar stopword dalam bahasa indonesia
stopwords = nltk.corpus.stopwords.words("indonesian")

# %%
# Remove stopwords
df['content_token'] = df['content_token'].apply(lambda x: [item for item in x if item not in stopwords])
df.head(3)
# Out:
#                                                content  score  Year  Month  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1  2023     10
# 866  developer jangan korupsi ya  saya yakin sekela...      1  2023     10
# 870  gojek loading doang tapi tidak bisa digunakan ...      1  2023     10
#
#      Day  sentiment                                      content_token
# 864   13         -1  [minimal, perubahan, bagus, napa, kagak, perub...
# 866   14         -1  [developer, korupsi, ya, sekelas, gojek, menga...
# 870   14         -1  [gojek, loading, doang, udah, diuninstal, n, d...

# %% [markdown]
# # Stemming sastrawi
# Sastrawi Python adalah library python sederhana yang memungkinkan Anda untuk mereduksi kata-kata infleksi dalam Bahasa Indonesia (Bahasa Indonesia) ke bentuk dasarnya (stem).

# %%
# !pip install Sastrawi #instal modul sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df['stemmed'] = df['content_token'].apply(lambda x: [stemmer.stem(y) for y in x]) #proses stemming setiap kata

# %%
df.head(5)
# Out:
#                                                content  score  Year  Month  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1  2023     10
# 866  developer jangan korupsi ya  saya yakin sekela...      1  2023     10
# 870  gojek loading doang tapi tidak bisa digunakan ...      1  2023     10
# 484  entah mengapa jadi lebih sering force close  l...      2  2023     10
# 869  perpindahan antar menu jadi sering error  seri...      1  2023     10
#
#      Day  sentiment                                      content_token  \
# 864   13         -1  [minimal, perubahan, bagus, napa, kagak, perub...
# 866   14         -1  [developer, korupsi, ya, sekelas, gojek, menga...
# 870   14         -1  [gojek, loading, doang, udah, diuninstal, n, d...
# 484   17         -1  [force, close, lag, crash, jaringan, jaringan,...
# 869   17         -1  [perpindahan, menu, error, dapet, driver, yg, ...
#
#                                                stemmed
# 864  [minimal, ubah, bagus, napa, kagak, ubah, gak,...
# 866  [developer, korupsi, ya, kelas, gojek, anggar,...
# 870  [gojek, loading, doang, udah, diuninstal, n, d...
# 484  [force, close, lag, crash, jaring, jaring, lem...
# 869  [pindah, menu, error, dapet, driver, yg, doubl...

# %%
df['text_string'] = df['stemmed'].apply(lambda x: ' '.join([item for item in x if len(item)>2])) #merubah da

# %%
df.head(5)
# Out:
#                                                content  score  Year  Month  \
# 864  minimal kalau mau perubahan yang lebih bagus n...      1  2023     10
# 866  developer jangan korupsi ya  saya yakin sekela...      1  2023     10
# 870  gojek loading doang tapi tidak bisa digunakan ...      1  2023     10
# 484  entah mengapa jadi lebih sering force close  l...      2  2023     10
# 869  perpindahan antar menu jadi sering error  seri...      1  2023     10
#
#      Day  sentiment                                      content_token  \
# 864   13         -1  [minimal, perubahan, bagus, napa, kagak, perub...
# 866   14         -1  [developer, korupsi, ya, sekelas, gojek, menga...
# 870   14         -1  [gojek, loading, doang, udah, diuninstal, n, d...
# 484   17         -1  [force, close, lag, crash, jaringan, jaringan,...
# 869   17         -1  [perpindahan, menu, error, dapet, driver, yg, ...
#
#                                                stemmed  \
# 864  [minimal, ubah, bagus, napa, kagak, ubah, gak,...
# 866  [developer, korupsi, ya, kelas, gojek, anggar,...
# 870  [gojek, loading, doang, udah, diuninstal, n, d...
# 484  [force, close, lag, crash, jaring, jaring, lem...
# 869  [pindah, menu, error, dapet, driver, yg, doubl...
#
#                                            text_string
# 864  minimal ubah bagus napa kagak ubah gak pakai i...
# 866  developer korupsi kelas gojek anggar dana serv...
# 870  gojek loading doang udah diuninstal download v...
# 484  force close lag crash jaring jaring lemah apli...
# 869  pindah menu error dapet driver double order pe...

# %% [markdown]
# # WORDCLOUD
# wordcloud digunakan untuk memunculkan citraan visual dari sebuah teks tertulis kemudian dapat dijadikan sebagai sebuah alat bantu dalam melakukan analisis teks. kata-kata yang ada digambarkan kedalam suatu visualisasi dimana besar kecilnya huruf bergantung pada frekuensi munculnya kata tersebut didalam teks. singkatnya adalah kata terbesar adalah kata yang paling sering muncul dalam suatu data.

# %%
# !pip install wordcloud #install library wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # wordcloud sentimen positif

# %%
df_p=df[df['sentiment']==1] #memfilter kolom sentiment = 1 (positif)

# %%
all_words_lem = ' '.join([word for word in df_p['text_string']]) #menggabungkan semua isi kolom text_string

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Assuming 'all_words_lem' is a string containing your preprocessed words
wordcloud = WordCloud(width=600,
                     height=400,
                     random_state=2,
                     max_font_size=100).generate(all_words_lem)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # wordcloud sentimen negatif

# %%
df_neg=df[df['sentiment']==-1] #memfilter kolom sentiment = -1 (negative)
all_words_lemneg = ' '.join([word for word in df_neg['text_string']]) #menggabungkan semua isi kolom text_s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width=600,
                     height=400,
                     random_state=2,
                     max_font_size=100).generate(all_words_lemneg)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# # wordcloud sentimen netral
#
# *   List item
# *   List item

# %%
df_net=df[df['sentiment']==0] #memfilter kolom sentiment = 0 (netral)
all_words_lemnet = ' '.join([word for word in df_net['text_string']]) #menggabungkan semua isi kolom text_st

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width=600,
                     height=400,
                     random_state=2,
                     max_font_size=100).generate(all_words_lemnet)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %%
df['text_string'] #menampilkan kolom text_string
# Out:
# 864    minimal ubah bagus napa kagak ubah gak pakai i...
# 866    developer korupsi kelas gojek anggar dana serv...
# 870    gojek loading doang udah diuninstal download v...
# 484    force close lag crash jaring jaring lemah apli...
# 869    pindah menu error dapet driver double order pe...
#                              ...
# 53     sen udh pake vocer gabisa muncul notif vocer o...
# 111    pesan gojek tdk batal driver salah angkut tump...
# 905    kesal banget gofood pesan gabisa dibatalin det...
# 464    harga mahal wkwkw gaco ribu lvl kalo sono beda...
# 946    update kalo saldo hilang saldo gua pas 100 hilang
# Name: text_string, Length: 995, dtype: object

# %%
# Basic Operation
import pandas as pd
import numpy as np

# Text Preprocessing & Cleaning
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re
from wordcloud import WordCloud,STOPWORDS
from nltk import SnowballStemmer


from sklearn.model_selection import train_test_split # Split Data
from imblearn.over_sampling import SMOTE # Handling Imbalanced

# Model Building
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.svm import SVC


from sklearn.metrics import classification_report , confusion_matrix , accuracy_score # Performance Metrics


# Data Visualization
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
import warnings


warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
X = df['text_string'] #X = kolom text_string
y = df['sentiment'] #y = kolom sentiment

# %%
#Apply TFIDF
tfid = TfidfVectorizer()
X_final =  tfid.fit_transform(X)

#HANDLING IMBALANCE
# Handling imbalanced using SMOTE
smote = SMOTE()
x_sm,y_sm = smote.fit_resample(X_final,y)

# %% [markdown]
# #Split Data into train & test

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.25,random_state=3)
#memisahkan data menjadi data train dan data test, dengan rincian dari 1000 data ada 750 sebagai data train dan

# %% [markdown]
# MODELLING, KLASIFIKASI DAN SKOR AKURASI BERDASARKAN MASING2 ALGORITMA

# %% [markdown]
# # Random Forest

# %%
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)

# %%
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.9292364990689013

# %% [markdown]
# # Support vector machine

# %%
svm = SVC()
svm.fit(X_train,y_train)
SVC()
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.9720670391061452
